# %%
import json
import pandas as pd

# %%
with open('제주도_1km_격자.json', mode = 'rt', encoding = 'utf-8') as f:
    js_file = json.loads(f.read())
    f.close()

# %%
grid = pd.read_csv('제주시_카드_월별_사용량_그리드1km.csv', encoding = 'euc_kr')
grid
# Out:
#       base_year_month  bjd     grid_1km  user_cnt
# 0              201901  건입동  10004330902       201
# 1              201901  건입동  10004330903     31181
# 2              201901  건입동  10004331002      6783
# 3              201901  건입동  10004331003     15311
# 4              201901  건입동  10004331101        29
# ...               ...  ...          ...       ...
# 7697           201912  회천동  10004321998      1765
# 7698           201912  회천동  10004331601         9
# 7699           201912  회천동  10004331700         2
# 7700           201912  회천동  10004331701        92
# 7701           201912  회천동  10004331801       124
#
# [7702 rows x 4 columns]

# %%
js_file
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.141, 33.313],
#       [126.136, 33.313],
#       [126.136, 33.308],
#       [126.141, 33.309],
#       [126.141, 33.313]]]},
#    'properties': {'left': 873000,
#     'top': 1481000,
#     'right': 873500,
#     'bottom': 1480500,
#     '1000_cd': '나나7380',
#     'xcoord': 873250,
#     'ycoord': 1480750,
#     'j_500_cd': 500322738010001,
#     'j_1000_cd': 10004227380,
#     'sigungu_nm': '',
#     'sigungu_cd': None,
#     'sido_nm': '',
#     'sido_cd': None,
#     'emd_eng_nm': '',
#     'emd_kor_nm': '',
#     'emd_cd': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.136, 33.308],
#       [126.136, 33.304],
#       [126.141, 33.304],
#       [126.141, 33.309],
#       [126.136, 33.308]]]},
#    'properties': {'left': 873000,
#     'top': 1480500,
#     'right': 873500,
#     'bottom': 1480000,
# ...

# %%
grid.head(3)
# Out:
#    base_year_month  bjd     grid_1km  user_cnt
# 0           201901  건입동  10004330902       201
# 1           201901  건입동  10004330903     31181
# 2           201901  건입동  10004331002      6783

# %%
a = grid[grid.base_year_month == 201901]
a.drop(['base_year_month'], axis = 1, inplace = True)
a['grid_1km'].unique()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# array([10004330902, 10004330903, 10004331002, 10004331003, 10004331101,
#        10004331102, 10004331103, 10004331104, 10004331202, 10004322893,
#        10004322894, 10004322992, 10004322993, 10004322997, 10004322999,
#        10004323092, 10004323099, 10004323195, 10004323198, 10004323297,
#        10004323396, 10004323397, 10004323398, 10004323497, 10004323599,
#        10004323796, 10004323897, 10004324499, 10004324599, 10004332605,
#        10004332606, 10004332607, 10004332706, 10004332707, 10004332807,
#        10004332903, 10004332906, 10004332907, 10004333000, 10004333005,
#        10004333006, 10004333007, 10004333107, 10004333201, 10004333204,
# ...
