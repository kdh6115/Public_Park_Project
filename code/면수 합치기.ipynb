# %%
import pandas as pd

# %%
df = pd.read_csv('data/주차장_경도+위도.csv', encoding = 'euc_kr')
df
# Out:
#          주차장                  주소 유형(유료/무료/민영)        경도        위도  시군구   법정동  \
# 0    용두암 주차장        제주시 용담이동 483           유료  261955.0  103108.0  제주시  용담이동
# 1    공항입구주차장       제주시 용담이동 1611           유료  260392.0  101927.0  제주시  용담이동
# 2    탐동제2주차장       제주시 삼도이동 1257           유료  262692.0  103462.0  제주시  삼도이동
# 3        칠성골     제주시 삼도이동 1192-8           유료  263186.0  103254.0  제주시  삼도이동
# 4    고산동산주차장    제주시 이도이동 1012-10           유료  263733.0  100934.0  제주시  이도이동
# ..       ...                 ...          ...       ...       ...  ...   ...
# 311    이도2지구     제주시 이도이동 2017-1           무료  264381.0  100119.0  제주시  이도이동
# 312    이도2지구     제주시 이도이동 1992-7           무료  264324.0  100479.0  제주시  이도이동
# 313    이도2지구     제주시 이도이동 1994-1           무료  264404.0  100599.0  제주시  이도이동
# 314    이도2지구     제주시 이도이동 1977-7           무료  264601.0  100421.0  제주시  이도이동
# 315    이도2지구  \t제주시 이도이동 1982-17           무료  264548.0  100195.0  제주시  이도이동
#
#       면수
# 0     62
# 1    379
# 2    107
# ...

# %%
df2 = df.iloc[:,-2:]
df2 = df2.groupby(['법정동']).sum()
df2.sort_values('면수', ascending = False)
# Out:
#         면수
# 법정동
# 이도이동  1700
# 노형동   1587
# 도두동    897
# 오라동    836
# 연동     832
# 이호동    785
# 아라동    784
# 용담이동   773
# 일도이동   690
# 삼양동    630
# 삼도이동   618
# 이도일동   592
# 외도동    514
# 일도일동   486
# 건입동    370
# 봉개동    327
# 화북동    322
# 삼도일동   151
# 조천리     79
# 오라일동    71
# 오라삼동    58
# 용담일동    55
# 한림리     47
# 해안동     42
# 연평리     38
# 아라이동    37
# 북촌리     36
# 함덕리     33
# 하귀일리    28
# 와흘리     27
# 삼양이동    26
# 상귀리     21
# 이호일동    19
# 고내리      8
# 오라이동     6
# 월림리      6
# 상도리      4
# 도평동      4
# 화북일동     2
