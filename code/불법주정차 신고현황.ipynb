# %%
import pandas as pd

# %%
catch = pd.read_csv("제주도_불법주정차 신고현황 .csv", encoding = "euc_kr")
catch
# Out:
#     구분  제주특별자치도   제주시  서귀포시
# 0   소계     7443  6603   840
# 1   4월      198   165    33
# 2   5월      852   715   137
# 3   6월      965   866    99
# 4   7월      733   663    70
# 5   8월      849   774    75
# 6   9월      870   782    88
# 7  10월     1168  1105    63
# 8  11월      849   729   120
# 9  12월      959   804   155

# %%
catch = catch.iloc[1:,]
catch
# Out:
#     구분  제주특별자치도   제주시  서귀포시
# 1   4월      198   165    33
# 2   5월      852   715   137
# 3   6월      965   866    99
# 4   7월      733   663    70
# 5   8월      849   774    75
# 6   9월      870   782    88
# 7  10월     1168  1105    63
# 8  11월      849   729   120
# 9  12월      959   804   155

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(
    fname = 'c:/Windows/Fonts/malgun.ttf').get_name()
rc('font', family=font_name)

plt.title("불법주정차 신고현황")
plt.bar(catch['구분'], catch['제주특별자치도'])
# Out:
# <BarContainer object of 9 artists>
